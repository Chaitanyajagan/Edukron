# %% [markdown]
# <a href="https://colab.research.google.com/github/Chaitanyajagan/Edukron-exercise/blob/main/ex2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
bank = [
    [ # Bank 1
        [ # Branch 1 of Bank 1
            ["C101", "Rahul", "Savings", 85000],
            ["C102", "Anita", "Current", 150000],
            ["C103", "Kiran", "Loan", 500000]
        ],
        [ # Branch 2 of Bank 1
            ["C104", "Sneha", "Savings", 95000],
            ["C105", "Vikram", "Current", 275000],
            ["C106", "Meena", "Loan", 750000]
        ]
    ],
    [ # Bank 2
        [ # Branch 1 of Bank 2
            ["C201", "Arjun", "Savings", 120000],
            ["C202", "Pooja", "Current", 325000],
            ["C203", "Ramesh", "Loan", 900000]
        ],
        [ # Branch 2 of Bank 2
            ["C204", "Priya", "Savings", 45000],
            ["C205", "Amit", "Current", 185000],
            ["C206", "Divya", "Loan", 650000]
        ]
    ],
    [ # Bank 3
        [ # Branch 1 of Bank 3
            ["C301", "Nikhil", "Savings", 78000],
            ["C302", "Kavya", "Current", 240000],
            ["C303", "Suresh", "Loan", 1000000]
        ],
        [ # Branch 2 of Bank 3
            ["C304", "Neha", "Savings", 135000],
            ["C305", "Rohan", "Current", 410000],
            ["C306", "Asha", "Loan", 550000]
        ]
    ]
]

print(bank[0][0][0])
# Out:
# ['C101', 'Rahul', 'Savings', 85000]

# %%
'''Print Rahul's complete record.

Print Anita's account type.

Print Kiran's loan amount.

Print Sneha's customer ID.

Print Vikram's balance.

Print Meena's complete record.

Print Arjun's customer ID.

Print Pooja's name.

Print Ramesh's account type.

Print Priya's balance.

Print Amit's account type.

Print Divya's customer ID.

Print Nikhil's account type.

Print Kavya's balance.

Print Suresh's loan amount.

Print Neha's name.

Print Rohan's complete record.

Print Asha's account type.

Print all customers in Bank 1, Branch 1.

Print all customers in Bank 1, Branch 2.

Print all customers in Bank 2, Branch 1.

Print all customers in Bank 2, Branch 2.

Print all customers in Bank 3, Branch 1.

Print all customers in Bank 3, Branch 2.

Print all branches of Bank 1.

Print all branches of Bank 2.

Print all branches of Bank 3.

Print the first customer from every bank's first branch.

Print the second customer from every bank's second branch.

Print the loan amount of the last customer in Bank 3, Branch 2.
     '''
# Out:
# "Print Rahul's complete record.\n\nPrint Anita's account type.\n\nPrint Kiran's loan amount.\n\nPrint Sneha's customer ID.\n\nPrint Vikram's balance.\n\nPrint Meena's complete record.\n\nPrint Arjun's customer ID.\n\nPrint Pooja's name.\n\nPrint Ramesh's account type.\n\nPrint Priya's balance.\n\nPrint Amit's account type.\n\nPrint Divya's customer ID.\n\nPrint Nikhil's account type.\n\nPrint Kavya's balance.\n\nPrint Suresh's loan amount.\n\nPrint Neha's name.\n\nPrint Rohan's complete record.\n\nPrint Asha's account type.\n\nPrint all customers in Bank 1, Branch 1.\n\nPrint all customers in Bank 1, Branch 2.\n\nPrint all customers in Bank 2, Branch 1.\n\nPrint all customers in Bank 2, Branch 2.\n\nPrint all customers in Bank 3, Branch 1.\n\nPrint all customers in Bank 3, Branch 2.\n\nPrint all branches of Bank 1.\n\nPrint all branches of Bank 2.\n\nPrint all branches of Bank 3.\n\nPrint the first customer from every bank's first branch.\n\nPrint the second customer from every bank's second branch.\n\nPrint the loan amount of the last customer in Bank 3, Branch 2.\n     "

# %%
# Print Rahul's complete record.
print("Rahul's complete record:", bank[0][0][0])
# Out:
# Rahul's complete record: ['C101', 'Rahul', 'Savings', 85000]

# %%
# Print Anita's account type.
print("Anita's account type:", bank[0][0][1][2])
# Out:
# Anita's account type: Current

# %%
# Print Kiran's loan amount.
print("Kiran's loan amount:", bank[0][0][2][3])
# Out:
# Kiran's loan amount: 500000

# %%
# Print Sneha's customer ID.
print("Sneha's customer ID:", bank[0][1][0][0])
# Out:
# Sneha's customer ID: C104

# %%
# Print Vikram's balance.
print("Vikram's balance:", bank[0][1][1][3])
# Out:
# Vikram's balance: 275000

# %%
# Print Meena's complete record.
print("Meena's complete record:", bank[0][1][2])
# Out:
# Meena's complete record: ['C106', 'Meena', 'Loan', 750000]

# %%
# Print Arjun's customer ID.
print("Arjun's customer ID:", bank[1][0][0][0])
# Out:
# Arjun's customer ID: C201

# %%
# Print Pooja's name.
print("Pooja's name:", bank[1][0][1][1])
# Out:
# Pooja's name: Pooja

# %%
# Print Ramesh's account type.
print("Ramesh's account type:", bank[1][0][2][2])
# Out:
# Ramesh's account type: Loan

# %%
# Print Priya's balance.
print("Priya's balance:", bank[1][1][0][3])
# Out:
# Priya's balance: 45000

# %%
# Print Amit's account type.
print("Amit's account type:", bank[1][1][1][2])
# Out:
# Amit's account type: Current

# %%
# Print Divya's customer ID.
print("Divya's customer ID:", bank[1][1][2][0])
# Out:
# Divya's customer ID: C206

# %%
# Print Nikhil's account type.
print("Nikhil's account type:", bank[2][0][0][2])
# Out:
# Nikhil's account type: Savings

# %%
# Print Kavya's balance.
print("Kavya's balance:", bank[2][0][1][3])
# Out:
# Kavya's balance: 240000

# %%
# Print Suresh's loan amount.
print("Suresh's loan amount:", bank[2][0][2][3])
# Out:
# Suresh's loan amount: 1000000

# %%
# Print Neha's name.
print("Neha's name:", bank[2][1][0][1])
# Out:
# Neha's name: Neha

# %%
# Print Rohan's complete record.
print("Rohan's complete record:", bank[2][1][1])
# Out:
# Rohan's complete record: ['C305', 'Rohan', 'Current', 410000]

# %%
# Print Asha's account type.
print("Asha's account type:", bank[2][1][2][2])
# Out:
# Asha's account type: Loan

# %%
# Print all customers in Bank 1, Branch 1.
print("Customers in Bank 1, Branch 1:", bank[0][0])
# Out:
# Customers in Bank 1, Branch 1: [['C101', 'Rahul', 'Savings', 85000], ['C102', 'Anita', 'Current', 150000], ['C103', 'Kiran', 'Loan', 500000]]

# %%
# Print all customers in Bank 1, Branch 2.
print("Customers in Bank 1, Branch 2:", bank[0][1])
# Out:
# Customers in Bank 1, Branch 2: [['C104', 'Sneha', 'Savings', 95000], ['C105', 'Vikram', 'Current', 275000], ['C106', 'Meena', 'Loan', 750000]]

# %%
# Print all customers in Bank 2, Branch 1.
print("Customers in Bank 2, Branch 1:", bank[1][0])
# Out:
# Customers in Bank 2, Branch 1: [['C201', 'Arjun', 'Savings', 120000], ['C202', 'Pooja', 'Current', 325000], ['C203', 'Ramesh', 'Loan', 900000]]

# %%
# Print all customers in Bank 2, Branch 2.
print("Customers in Bank 2, Branch 2:", bank[1][1])
# Out:
# Customers in Bank 2, Branch 2: [['C204', 'Priya', 'Savings', 45000], ['C205', 'Amit', 'Current', 185000], ['C206', 'Divya', 'Loan', 650000]]

# %%
# Print all customers in Bank 3, Branch 1.
print("Customers in Bank 3, Branch 1:", bank[2][0])
# Out:
# Customers in Bank 3, Branch 1: [['C301', 'Nikhil', 'Savings', 78000], ['C302', 'Kavya', 'Current', 240000], ['C303', 'Suresh', 'Loan', 1000000]]

# %%
# Print all customers in Bank 3, Branch 2.
print("Customers in Bank 3, Branch 2:", bank[2][1])
# Out:
# Customers in Bank 3, Branch 2: [['C304', 'Neha', 'Savings', 135000], ['C305', 'Rohan', 'Current', 410000], ['C306', 'Asha', 'Loan', 550000]]

# %%
# Print all branches of Bank 1.
print("Branches of Bank 1:", bank[0])
# Out:
# Branches of Bank 1: [[['C101', 'Rahul', 'Savings', 85000], ['C102', 'Anita', 'Current', 150000], ['C103', 'Kiran', 'Loan', 500000]], [['C104', 'Sneha', 'Savings', 95000], ['C105', 'Vikram', 'Current', 275000], ['C106', 'Meena', 'Loan', 750000]]]

# %%
# Print all branches of Bank 2.
print("Branches of Bank 2:", bank[1])
# Out:
# Branches of Bank 2: [[['C201', 'Arjun', 'Savings', 120000], ['C202', 'Pooja', 'Current', 325000], ['C203', 'Ramesh', 'Loan', 900000]], [['C204', 'Priya', 'Savings', 45000], ['C205', 'Amit', 'Current', 185000], ['C206', 'Divya', 'Loan', 650000]]]

# %%
# Print all branches of Bank 3.
print("Branches of Bank 3:", bank[2])
# Out:
# Branches of Bank 3: [[['C301', 'Nikhil', 'Savings', 78000], ['C302', 'Kavya', 'Current', 240000], ['C303', 'Suresh', 'Loan', 1000000]], [['C304', 'Neha', 'Savings', 135000], ['C305', 'Rohan', 'Current', 410000], ['C306', 'Asha', 'Loan', 550000]]]

# %%
# Print the first customer from every bank's first branch.
print("First customer from Bank 1, Branch 1:", bank[0][0][0])
print("First customer from Bank 2, Branch 1:", bank[1][0][0])
print("First customer from Bank 3, Branch 1:", bank[2][0][0])
# Out:
# First customer from Bank 1, Branch 1: ['C101', 'Rahul', 'Savings', 85000]
# First customer from Bank 2, Branch 1: ['C201', 'Arjun', 'Savings', 120000]
# First customer from Bank 3, Branch 1: ['C301', 'Nikhil', 'Savings', 78000]

# %%
# Print the second customer from every bank's second branch.
print("Second customer from Bank 1, Branch 2:", bank[0][1][1])
print("Second customer from Bank 2, Branch 2:", bank[1][1][1])
print("Second customer from Bank 3, Branch 2:", bank[2][1][1])
# Out:
# Second customer from Bank 1, Branch 2: ['C105', 'Vikram', 'Current', 275000]
# Second customer from Bank 2, Branch 2: ['C205', 'Amit', 'Current', 185000]
# Second customer from Bank 3, Branch 2: ['C305', 'Rohan', 'Current', 410000]

# %%
# Print the loan amount of the last customer in Bank 3, Branch 2.
print("Loan amount of the last customer in Bank 3, Branch 2:", bank[2][1][2][3])
# Out:
# Loan amount of the last customer in Bank 3, Branch 2: 550000
